# %%
import pandas as pd

# %%
df = pd.read_csv('earthquakes.csv')

# %%
# Grab an entire column using attribute notation:
df.mag
# Out:
# 0       4.90
# 1       0.68
# 2       1.90
# 3       2.15
# 4       2.00
#         ...
# 6741    3.00
# 6742    0.54
# 6743    0.28
# 6744    1.07
# 6745    0.08
# Name: mag, Length: 6746, dtype: float64

# %%
# Grab an entire column using dictionary syntax:
df['mag']
# Out:
# 0       4.90
# 1       0.68
# 2       1.90
# 3       2.15
# 4       2.00
#         ...
# 6741    3.00
# 6742    0.54
# 6743    0.28
# 6744    1.07
# 6745    0.08
# Name: mag, Length: 6746, dtype: float64

# %%
# Selecting multiple columns:
df[['mag', 'title']]
# Out:
#        mag                                              title
# 0     4.90  M 4.9 - 191 km ESE of Ust’-Kamchatsk Staryy, R...
# 1     0.68                       M 0.7 - 7 km WNW of Cobb, CA
# 2     1.90         M 1.9 - 20 km W of Point MacKenzie, Alaska
# 3     2.15                      M 2.2 - 4 km W of Magalia, CA
# 4     2.00           M 2.0 - 33 km WNW of Petersville, Alaska
# ...    ...                                                ...
# 6741  3.00                 M 3.0 - 26 km NNE of Chase, Alaska
# 6742  0.54                 M 0.5 - 9 km ENE of San Martin, CA
# 6743  0.28                M 0.3 - 8 km NNW of The Geysers, CA
# 6744  1.07                 M 1.1 - 20 km E of Little Lake, CA
# 6745  0.08               M 0.1 - 77 km W of Salamatof, Alaska
#
# [6746 rows x 2 columns]

# %%
# Selecting columns using list comprehensions and string operations offered by pandas Series objects:
df[
    ['title', 'time']
    + [col for col in df.columns if col.startswith('mag')]
]
# Out:
#                                                   title           time   mag  \
# 0     M 4.9 - 191 km ESE of Ust’-Kamchatsk Staryy, R...  1731369384328  4.90
# 1                          M 0.7 - 7 km WNW of Cobb, CA  1731367157080  0.68
# 2            M 1.9 - 20 km W of Point MacKenzie, Alaska  1731366482588  1.90
# 3                         M 2.2 - 4 km W of Magalia, CA  1731366324690  2.15
# 4              M 2.0 - 33 km WNW of Petersville, Alaska  1731365892605  2.00
# ...                                                 ...            ...   ...
# 6741                 M 3.0 - 26 km NNE of Chase, Alaska  1729126041870  3.00
# 6742                 M 0.5 - 9 km ENE of San Martin, CA  1729125111440  0.54
# 6743                M 0.3 - 8 km NNW of The Geysers, CA  1729124975210  0.28
# 6744                 M 1.1 - 20 km E of Little Lake, CA  1729124731770  1.07
# 6745               M 0.1 - 77 km W of Salamatof, Alaska  1729124218900  0.08
#
#      magType
# 0         mb
# 1         md
# 2         ml
# 3         md
# 4         ml
# ...      ...
# 6741      ml
# 6742      md
# 6743      md
# 6744      ml
# 6745      ml
#
# [6746 rows x 4 columns]

# %%
# Breaking down this example:
# 1- the list comprehension:
[col for col in df.columns if col.startswith('mag')]
# Out:
# ['mag', 'magType']

# %%
# 2- assembling the list:
['title', 'time'] \
+ [col for col in df.columns if col.startswith('mag')]
# Out:
# ['title', 'time', 'mag', 'magType']

# %%
# 3-using this list as the list of columns:
df[
    ['title', 'time']
    + [col for col in df.columns if col.startswith('mag')]
]
# Out:
#                                                   title           time   mag  \
# 0     M 4.9 - 191 km ESE of Ust’-Kamchatsk Staryy, R...  1731369384328  4.90
# 1                          M 0.7 - 7 km WNW of Cobb, CA  1731367157080  0.68
# 2            M 1.9 - 20 km W of Point MacKenzie, Alaska  1731366482588  1.90
# 3                         M 2.2 - 4 km W of Magalia, CA  1731366324690  2.15
# 4              M 2.0 - 33 km WNW of Petersville, Alaska  1731365892605  2.00
# ...                                                 ...            ...   ...
# 6741                 M 3.0 - 26 km NNE of Chase, Alaska  1729126041870  3.00
# 6742                 M 0.5 - 9 km ENE of San Martin, CA  1729125111440  0.54
# 6743                M 0.3 - 8 km NNW of The Geysers, CA  1729124975210  0.28
# 6744                 M 1.1 - 20 km E of Little Lake, CA  1729124731770  1.07
# 6745               M 0.1 - 77 km W of Salamatof, Alaska  1729124218900  0.08
#
#      magType
# 0         mb
# 1         md
# 2         ml
# 3         md
# 4         ml
# ...      ...
# 6741      ml
# 6742      md
# 6743      md
# 6744      ml
# 6745      ml
#
# [6746 rows x 4 columns]

# %%
# Using row numbers (inclusive of first index, exclusive of last):
df[100:103]
# Out:
#       mag                               place           time        updated  \
# 100  2.70  55 km S of Whites City, New Mexico  1731322030800  1731336673174
# 101  0.70               22 km ESE of Anza, CA  1731321593400  1731339106987
# 102  1.36              3 km SSE of Muscoy, CA  1731321042860  1731347588310
#
#      tz                                                url  \
# 100 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 101 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 102 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                 detail  felt  cdi  mmi  ...  \
# 100  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  3.1  NaN  ...
# 101  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 102  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#                          ids  sources  \
# 100  ,tx2024weiy,us7000nr53,  ,tx,us,
# 101             ,ci40791567,     ,ci,
# 102             ,ci40791559,     ,ci,
#
#                                                  types   nst     dmin   rms  \
# 100                           ,dyfi,origin,phase-data,  33.0  0.10000  0.10
# 101     ,nearby-cities,origin,phase-data,scitech-link,  43.0  0.09866  0.17
# 102  ,focal-mechanism,nearby-cities,origin,phase-da...  95.0  0.02822  0.17
#
#       gap magType        type                                       title
# 100  68.0      ml  earthquake  M 2.7 - 55 km S of Whites City, New Mexico
# 101  81.0      ml  earthquake               M 0.7 - 22 km ESE of Anza, CA
# 102  27.0      ml  earthquake              M 1.4 - 3 km SSE of Muscoy, CA
#
# [3 rows x 26 columns]

# %%
# Selecting rows and columns with chaining:
df[['title', 'time']][100:153]
# Out:
#                                                  title           time
# 100         M 2.7 - 55 km S of Whites City, New Mexico  1731322030800
# 101                      M 0.7 - 22 km ESE of Anza, CA  1731321593400
# 102                     M 1.4 - 3 km SSE of Muscoy, CA  1731321042860
# 103             M 1.7 - 101 km WNW of Skwentna, Alaska  1731320673300
# 104                   M 1.3 - 30 km W of Ester, Alaska  1731320229522
# 105  M 5.6 - Maug Islands region, Northern Mariana ...  1731320218633
# 106               M 4.9 - 111 km NW of Tual, Indonesia  1731319701798
# 107        M 0.9 - 11 km ESE of Indian Springs, Nevada  1731319539733
# 108                       M 0.4 - 11 km SE of Anza, CA  1731318947920
# 109                 M 1.8 - 9 km SW of Morgan Hill, CA  1731318940210
# 110                   M 1.3 - 25 km E of Forsan, Texas  1731317686171
# 111            M 1.2 - 86 km SE of King Salmon, Alaska  1731316734955
# 112         M 2.3 - 55 km S of Whites City, New Mexico  1731316627713
# 113                  M 1.8 - 5 km W of Susitna, Alaska  1731313982757
# 114              M 4.4 - 22 km ESE of Yapraklı, Turkey  1731313675271
# 115         M 0.2 - 8 km NNW of Indian Springs, Nevada  1731313631083
# 116       M -0.2 - 45 km WNW of Indian Springs, Nevada  1731313548721
# 117                  M 2.0 - 72 km W of Karluk, Alaska  1731313453053
# 118                   M 1.5 - 59 km NW of Toyah, Texas  1731313351469
# 119            M 4.2 - 41 km E of Farkhār, Afghanistan  1731313191211
# 120                  M 4.1 - 40 km SE of Molina, Chile  1731313169276
# 121             M 0.7 - 57 km NE of Keeler, California  1731312454658
# 122              M 1.9 - 15 km NNE of Fishhook, Alaska  1731311683299
# 123                    M 1.4 - 6 km SSE of Clayton, CA  1731311255250
# 124                 M 5.0 - 109 km E of ‘Ohonua, Tonga  1731309297929
# 125              M 1.5 - 55 km WSW of Tatitlek, Alaska  1731309098282
# 126                       M 0.8 - 6 km WNW of Cobb, CA  1731308451180
# 127               M 2.1 - 58 km SE of Cantwell, Alaska  1731308438219
# 128                       M 1.0 - 11 km NW of Cobb, CA  1731307906220
# 129         M 2.5 - 36 km SSW of Trapper Creek, Alaska  1731307476483
# 130             M 2.3 - 56 km N of Petersville, Alaska  1731307100656
# 131                       M 2.0 - 11 km SE of Anza, CA  1731306758140
# 132                       M 1.3 - 11 km SE of Anza, CA  1731306340760
# 133         M 1.0 - 11 km NNW of Virginia City, Nevada  1731304685412
# 134                   M 1.3 - 8 km E of Coahoma, Texas  1731304435010
# 135                M 1.8 - 2 km WNW of Enola, Arkansas  1731303685830
# 136         M 0.2 - 12 km NNW of Virginia City, Nevada  1731303480959
# 137                   M 3.1 - 26 km SE of Rio Dell, CA  1731303319290
# 138                M 1.1 - 31 km WSW of Ackerly, Texas  1731302786183
# 139                   M 1.2 - 2 km W of Mulino, Oregon  1731301641890
# 140            M 4.6 - 36 km WSW of Port-Vila, Vanuatu  1731301587145
# 141           M 0.5 - 23 km ENE of Ashford, Washington  1731300447270
# 142                 M 0.3 - 5 km NW of The Geysers, CA  1731299600660
# 143                M 1.2 - 17 km N of Balmorhea, Texas  1731299471339
# 144            M 0.1 - 12 km SE of Ashford, Washington  1731299052050
# 145                M 1.8 - 18 km SSE of Tyonek, Alaska  1731299017999
# 146                M 1.3 - 17 km WSW of Toms Place, CA  1731298849240
# 147                 M 5.0 - 118 km NE of Hihifo, Tonga  1731297775746
# 148                 M 1.6 - 5 km N of Cedar City, Utah  1731297653140
# 149                   M 0.5 - 44 km SE of Dyer, Nevada  1731297002473
# 150               M 2.3 - 70 km ENE of Nikolai, Alaska  1731296755000
# 151                  M 1.9 - 29 km W of Salcha, Alaska  1731296279344
# 152            M 1.0 - 15 km WSW of Ocotillo Wells, CA  1731294523880

# %%
# Order doesn't matter here:
df[100:103][['title', 'time']].equals(
    df[['title', 'time']][100:103]
)
# Out:
# True

# %%
df[100:113]['title']
# Out:
# 100           M 2.7 - 55 km S of Whites City, New Mexico
# 101                        M 0.7 - 22 km ESE of Anza, CA
# 102                       M 1.4 - 3 km SSE of Muscoy, CA
# 103               M 1.7 - 101 km WNW of Skwentna, Alaska
# 104                     M 1.3 - 30 km W of Ester, Alaska
# 105    M 5.6 - Maug Islands region, Northern Mariana ...
# 106                 M 4.9 - 111 km NW of Tual, Indonesia
# 107          M 0.9 - 11 km ESE of Indian Springs, Nevada
# 108                         M 0.4 - 11 km SE of Anza, CA
# 109                   M 1.8 - 9 km SW of Morgan Hill, CA
# 110                     M 1.3 - 25 km E of Forsan, Texas
# 111              M 1.2 - 86 km SE of King Salmon, Alaska
# 112           M 2.3 - 55 km S of Whites City, New Mexico
# Name: title, dtype: object

# %%
# Using loc:
df.loc[110:112, 'title'] = df.loc[110:112, 'title'].str.lower()
df.loc[110:112, 'title']
# Out:
# 110              m 1.3 - 25 km e of forsan, texas
# 111       m 1.2 - 86 km se of king salmon, alaska
# 112    m 2.3 - 55 km s of whites city, new mexico
# Name: title, dtype: object

# %%
# we can select all rows:
df.loc[:, 'title']
# Out:
# 0       M 4.9 - 191 km ESE of Ust’-Kamchatsk Staryy, R...
# 1                            M 0.7 - 7 km WNW of Cobb, CA
# 2              M 1.9 - 20 km W of Point MacKenzie, Alaska
# 3                           M 2.2 - 4 km W of Magalia, CA
# 4                M 2.0 - 33 km WNW of Petersville, Alaska
#                               ...
# 6741                   M 3.0 - 26 km NNE of Chase, Alaska
# 6742                   M 0.5 - 9 km ENE of San Martin, CA
# 6743                  M 0.3 - 8 km NNW of The Geysers, CA
# 6744                   M 1.1 - 20 km E of Little Lake, CA
# 6745                 M 0.1 - 77 km W of Salamatof, Alaska
# Name: title, Length: 6746, dtype: object

# %%
df.loc[10:15, ['title', 'mag']]
# Out:
#                                               title   mag
# 10               M 4.9 - 265 km WNW of Houma, Tonga  4.90
# 11         M 1.6 - 22 km N of Sutton-Alpine, Alaska  1.60
# 12                    M 1.8 - 5 km N of Fontana, CA  1.78
# 13         M 2.0 - 11 km SSE of Fern Forest, Hawaii  2.02
# 14  M 2.1 - 56 km SE of Pope-Vannoy Landing, Alaska  2.10
# 15               M 1.6 - 70 km ENE of Chase, Alaska  1.60

# %%
# Integer Location Indexing with iloc
# Exclusive of the endpoint just as Python slicing of lists:
df.iloc[10:15, [19,8]]
# Out:
#       nst  cdi
# 10  103.0  NaN
# 11    NaN  NaN
# 12   84.0  NaN
# 13   50.0  NaN
# 14    NaN  NaN

# %%
# We can use slicing syntax with iloc for both rows and columns:
df.iloc[10:15, 8:10]
# Out:
#     cdi  mmi
# 10  NaN  NaN
# 11  NaN  NaN
# 12  NaN  NaN
# 13  NaN  NaN
# 14  NaN  NaN

# %%
df.iloc[10:15, 8:10].equals(df.loc[10:14, 'mag':'magType'])
# Out:
# False

# %%
# we can use  take() method, which allows us to select specific row numbers (essentially iloc without having to specify the columns):
df.loc[10:14, 'mag':'magType'].take([1, 3])
# Out:
#      mag                             place           time        updated  tz  \
# 11  1.60  22 km N of Sutton-Alpine, Alaska  1731362578073  1731362792104 NaN
# 13  2.02  11 km SSE of Fern Forest, Hawaii  1731361832310  1731362010240 NaN
#
#                                                   url  \
# 11  https://earthquake.usgs.gov/earthquakes/eventp...
# 13  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                detail  felt  cdi  mmi  ...  \
# 11  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 13  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#    net        code             ids  sources                types   nst  \
# 11  ak  024eiyxr9r  ,ak024eiyxr9r,     ,ak,  ,origin,phase-data,   NaN
# 13  hv    74528247    ,hv74528247,     ,hv,  ,origin,phase-data,  50.0
#
#        dmin   rms    gap  magType
# 11      NaN  0.55    NaN       ml
# 13  0.02308  0.37  148.0       ml
#
# [2 rows x 24 columns]

# %%
# to look up scaler values, we use the faster at[] and iat[]:
df.at[10, 'mag']
# Out:
# 4.9

# %%
df.iat[10, 8]
# Out:
# nan

# %%
# We can filter our dataframes using a Boolean mask, which can be made as follows:
df.mag > 2
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 6741     True
# 6742    False
# 6743    False
# 6744    False
# 6745    False
# Name: mag, Length: 6746, dtype: bool

# %%
# To use a mask for selection, we simply place it inside the brackets:
df[df.mag >= 7]
# Out:
# Empty DataFrame
# Columns: [mag, place, time, updated, tz, url, detail, felt, cdi, mmi, alert, status, tsunami, sig, net, code, ids, sources, types, nst, dmin, rms, gap, magType, type, title]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.loc[
    df.mag >= 7.0,
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
# Empty DataFrame
# Columns: [alert, mag, magType, title, tsunami, type]
# Index: []

# %%
# usage & :
df.loc[
    (df.tsunami == 1) & (df.alert == 'red'),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
# Empty DataFrame
# Columns: [alert, mag, magType, title, tsunami, type]
# Index: []

# %%
# usage OR:
df.loc[
    (df.tsunami == 1) | (df.alert == 'red'),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#        alert   mag magType                                      title  \
# 228   yellow  6.80     mww  M 6.8 - 40 km SSW of Bartolomé Masó, Cuba
# 1812   green  5.80     mww          M 5.8 - 81 km ESE of Adak, Alaska
# 2813   green  6.00     mww         M 6.0 - 279 km W of Bandon, Oregon
# 4688   green  4.36      mw           M 4.4 - 5 km SSW of Petrolia, CA
#
#       tsunami        type
# 228         1  earthquake
# 1812        1  earthquake
# 2813        1  earthquake
# 4688        1  earthquake

# %%
# we can select all earthquakes with the string Alaska in the place column with a non-null value for the alert column. To get non-nulls, 
# we can use the isnull() method with the pandas negation operator (~) or the notnull() method:
df.loc[
    (df.place.str.contains('Alaska')) & (df.alert.notnull()),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert  mag magType                              title  tsunami  \
# 1812  green  5.8     mww  M 5.8 - 81 km ESE of Adak, Alaska        1
#
#             type
# 1812  earthquake

# %%
# we can say regular:
df.loc[
    (df.place.str.contains(r'CA|California$')) & (df.mag > 3.8),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert   mag magType                                    title  tsunami  \
# 4058    NaN  3.92      mw       M 3.9 - 127 km WNW of Petrolia, CA        0
# 4061  green  4.15      mw       M 4.2 - 118 km WNW of Petrolia, CA        0
# 4272  green  4.54      ml  M 4.5 - 10 km SE of Stovepipe Wells, CA        0
# 4348  green  4.72      mw    M 4.7 - 5 km E of Stovepipe Wells, CA        0
# 4366  green  4.17      mw    M 4.2 - 4 km E of Stovepipe Wells, CA        0
# 4686  green  3.92      mw         M 3.9 - 5 km SSW of Petrolia, CA        0
# 4688  green  4.36      mw         M 4.4 - 5 km SSW of Petrolia, CA        1
# 4696  green  4.00      mw         M 4.0 - 5 km SSW of Petrolia, CA        0
#
#             type
# 4058  earthquake
# 4061  earthquake
# 4272  earthquake
# 4348  earthquake
# 4366  earthquake
# 4686  earthquake
# 4688  earthquake
# 4696  earthquake

# %%
# usage between:
df.loc[
    df.mag.between(6.5, 7.5),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert  mag magType                                      title  tsunami  \
# 228  yellow  6.8     mww  M 6.8 - 40 km SSW of Bartolomé Masó, Cuba        1
#
#            type
# 228  earthquake

# %%
# isin() method to check for membership in a list of values:
df.loc[
    df.alert.isin(['orange', 'red']),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
# Empty DataFrame
# Columns: [alert, mag, magType, title, tsunami, type]
# Index: []

# %%
# We can grab the index of the minimum and maximum values of a given column and use those to select the entire row where they occur:
[df.mag.idxmin(), df.mag.idxmax()]
# Out:
# [5771, 228]

# %%
df.loc[(df.place.str.contains(r'CA | Calfornia$')) & 
(df.mag > 3.8), 
['alert', 'mag', 'magType', 'title', 'tsunami', 'type']]
# Out:
# Empty DataFrame
# Columns: [alert, mag, magType, title, tsunami, type]
# Index: []

# %%
df.place.str.contains('alaska')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6741    False
# 6742    False
# 6743    False
# 6744    False
# 6745    False
# Name: place, Length: 6746, dtype: bool

# %%
# Using the filter() method, we can grab columns of a dataframe by passing a list to items:
df.filter(items=['mag', 'magType']).head()
# Out:
#     mag magType
# 0  4.90      mb
# 1  0.68      md
# 2  1.90      ml
# 3  2.15      md
# 4  2.00      ml

# %%
# We can also grab all the columns that contain a string with the like parameter:
df.filter(like='mag').head()
# Out:
#     mag magType
# 0  4.90      mb
# 1  0.68      md
# 2  1.90      ml
# 3  2.15      md
# 4  2.00      ml

# %%
# We can even use regular expressions; here, we select any columns that start with t:
df.filter(regex=r'^t').head()
# Out:
#             time  tz  tsunami                                           types  \
# 0  1731369384328 NaN        0      ,internal-moment-tensor,origin,phase-data,
# 1  1731367157080 NaN        0  ,nearby-cities,origin,phase-data,scitech-link,
# 2  1731366482588 NaN        0                             ,origin,phase-data,
# 3  1731366324690 NaN        0  ,nearby-cities,origin,phase-data,scitech-link,
# 4  1731365892605 NaN        0                             ,origin,phase-data,
#
#          type                                              title
# 0  earthquake  M 4.9 - 191 km ESE of Ust’-Kamchatsk Staryy, R...
# 1  earthquake                       M 0.7 - 7 km WNW of Cobb, CA
# 2  earthquake         M 1.9 - 20 km W of Point MacKenzie, Alaska
# 3  earthquake                      M 2.2 - 4 km W of Magalia, CA
# 4  earthquake           M 2.0 - 33 km WNW of Petersville, Alaska

# %%
# we  use filter() along the rows, by passing in axis=0. Here we will use the place column as the index:
df.set_index('place').filter(like='Japan', axis=0).filter(items=['mag', 'magType', 'title']).head()
# Out:
#                                mag magType  \
# place
# Izu Islands, Japan region      4.9      mb
# Volcano Islands, Japan region  4.7      mb
# Volcano Islands, Japan region  4.9      mb
# 47 km SSE of Kushima, Japan    4.5      mb
# Volcano Islands, Japan region  4.9      mb
#
#                                                                title
# place
# Izu Islands, Japan region          M 4.9 - Izu Islands, Japan region
# Volcano Islands, Japan region  M 4.7 - Volcano Islands, Japan region
# Volcano Islands, Japan region  M 4.9 - Volcano Islands, Japan region
# 47 km SSE of Kushima, Japan      M 4.5 - 47 km SSE of Kushima, Japan
# Volcano Islands, Japan region  M 4.9 - Volcano Islands, Japan region

# %%
# we use Series objects and will run on the index:
df.set_index('place').title.filter(like='Japan').head()
# Out:
# place
# Izu Islands, Japan region            M 4.9 - Izu Islands, Japan region
# Volcano Islands, Japan region    M 4.7 - Volcano Islands, Japan region
# Volcano Islands, Japan region    M 4.9 - Volcano Islands, Japan region
# 47 km SSE of Kushima, Japan        M 4.5 - 47 km SSE of Kushima, Japan
# Volcano Islands, Japan region    M 4.9 - Volcano Islands, Japan region
# Name: title, dtype: object
